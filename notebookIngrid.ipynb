# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
cv2.__version__
# Out:
# '4.8.1'

# %%
import mss
with mss.mss() as sct:
    monitor = sct.monitors[1] # Use the first monitor
    width = monitor["width"] # Get the width of the screen
    height = monitor["height"] # Get the height of the screen

    top = height // 2 # The top pixel value is half of the height
    left = 0 # The left pixel value is zero
    right = width # The right pixel value is the same as the width
    bottom = height # The bottom pixel value is the same as the height
    # The screen part to capture
    #monitor = {"top": 0, "left": 0, "width": 1080, "height": 920}
    monitor = {"top": top, "left": left, "width": right, "height": bottom}
    output = "sct-{top}x{left}_{width}x{height}.png".format(**monitor)

    # Grab the data
    sct_img = sct.grab(monitor)

    # Save to the picture file
    mss.tools.to_png(sct_img.rgb, sct_img.size, output=output)
    print(output)
# Out:
# sct-540x0_1920x1080.png

# %%
import mss.tools
import time

time.sleep(20)
for i in range(10):
    time.sleep(2)
   
    output_folder = "ingridimages"
    with mss.mss() as sct:
        monitor_info = sct.monitors[0]

        # The screen part to capture
        monitor = {"top": monitor_info["top"] + monitor_info["height"] // 2, "left": monitor_info["left"], "width": monitor_info["width"], "height": monitor_info["height"] // 2}
        output = "ingridimages/sct-{top}x{left}_{width}x{height}{i}.png".format(**monitor)

        # Grab the data
        sct_img = sct.grab(monitor)

        # Save to the picture file
        mss.tools.to_png(sct_img.rgb, sct_img.size, output=output)
        print(output)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Untitled-1.ipynb Cell 2 line 1
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=9'>10</a> # The screen part to capture
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=10'>11</a> monitor = {"top": monitor_info["top"] + monitor_info["height"] // 2, "left": monitor_info["left"], "width": monitor_info["width"], "height": monitor_info["height"] // 2}
# ---> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=11'>12</a> output = "ingridimages/sct-{top}x{left}_{width}x{height}{i}.png".format(**monitor)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=13'>14</a> # Grab the data
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=14'>15</a> sct_img = sct.grab(monitor)
#
# KeyError: 'i'

# %%
import mss.tools
import os

# Specify the folder where you want to save the images
output_folder = "ingridimages"
time.sleep(20)
with mss.mss() as sct:
    monitor_info = sct.monitors[0]

    # The screen part to capture
    monitor = {"top": monitor_info["top"] + monitor_info["height"] // 2, "left": monitor_info["left"], "width": monitor_info["width"], "height": monitor_info["height"] // 2}

    # Run the loop 10 times
    for i in range(10):
        time.sleep(2)
        # Construct the full output path with the specified folder and loop variable i
        output = os.path.join(output_folder, "sct-{top}x{left}_{width}x{height}{i}.png".format(**monitor, i=i))

        # Grab the data
        sct_img = sct.grab(monitor)

        # Save to the picture file
        mss.tools.to_png(sct_img.rgb, sct_img.size, output=output)
        print(output)
# Out:
# ingridimages\sct-540x0_1920x5400.png
# ingridimages\sct-540x0_1920x5401.png
# ingridimages\sct-540x0_1920x5402.png
# ingridimages\sct-540x0_1920x5403.png
# ingridimages\sct-540x0_1920x5404.png
# ingridimages\sct-540x0_1920x5405.png
# ingridimages\sct-540x0_1920x5406.png
# ingridimages\sct-540x0_1920x5407.png
# ingridimages\sct-540x0_1920x5408.png
# ingridimages\sct-540x0_1920x5409.png

# %%
import mss.tools
import time
 
time.sleep(10)
 
with mss.mss() as sct:
    monitor_info = sct.monitors[0]
    top_margin = monitor_info["height"] // 3
    monitor = {"top": monitor_info["top"] + top_margin, "left": monitor_info["left"], "width": monitor_info["width"], "height": (monitor_info["height"] * 2 // 3)-55}
 
    for i in range(1, 21):
        output = f"ingridimages/{i}.png".format(**monitor)
        sct_img = sct.grab(monitor)
        mss.tools.to_png(sct_img.rgb, sct_img.size, output=output)
        print(f"Captured {output}")
        time.sleep(1)
# Out:
# Captured ingridimages/1.png
# Captured ingridimages/2.png
# Captured ingridimages/3.png
# Captured ingridimages/4.png
# Captured ingridimages/5.png
# Captured ingridimages/6.png
# Captured ingridimages/7.png
# Captured ingridimages/8.png
# Captured ingridimages/9.png
# Captured ingridimages/10.png
# Captured ingridimages/11.png
# Captured ingridimages/12.png
# Captured ingridimages/13.png
# Captured ingridimages/14.png
# Captured ingridimages/15.png
# Captured ingridimages/16.png
# Captured ingridimages/17.png
# Captured ingridimages/18.png
# Captured ingridimages/19.png
# Captured ingridimages/20.png

# %%
import uuid
import mss.tools
import time
 
time.sleep(5)
 
with mss.mss() as sct:
    monitor_info = sct.monitors[0]
    top_margin = monitor_info["height"] // 3
    monitor = {"top": monitor_info["top"] + top_margin, "left": monitor_info["left"]+55, "width": monitor_info["width"]-120, "height": (monitor_info["height"] * 2 // 3)-55}
 
    for i in range(1, 21):
        output = f"ingridimages/{str(uuid.uuid4())}.png".format(**monitor)
        sct_img = sct.grab(monitor)
        mss.tools.to_png(sct_img.rgb, sct_img.size, output=output)
        print(f"Captured {output}")
        time.sleep(1)
# Out:
# Captured ingridimages/875fd8c2-952b-4caa-a125-d62861f12f59.png
# Captured ingridimages/2dde6579-07a2-4fa7-ac02-cbf42424b6c6.png
# Captured ingridimages/0609e89b-d4f9-41d2-900d-5486b024ec34.png
# Captured ingridimages/872c0559-9fff-4974-a1e5-66260b4dea36.png
# Captured ingridimages/f868019f-e942-4d44-8e60-79bd4e3b1b7a.png
# Captured ingridimages/4b02341e-9522-4377-9a38-cbbed50646be.png
# Captured ingridimages/fd73b961-60d9-4cbb-a249-fadae7348ce9.png
# Captured ingridimages/bc04bece-23bb-4a1d-ad69-d42df89cbc8e.png
# Captured ingridimages/ad81713d-74f1-4958-8f67-5c63b8d1ad97.png
# Captured ingridimages/8755b4a5-169c-4182-814a-c9bf66f0cc01.png
# Captured ingridimages/4220e99b-0dfc-4108-a4e2-3964feb6ea69.png
# Captured ingridimages/f5d6d932-cc84-4d77-86a9-1850618c8e3b.png
# Captured ingridimages/4a7d1960-a031-459a-9b56-245a14b7db88.png
# Captured ingridimages/ee15b044-4d48-4f74-98ca-7ed45e05a881.png
# Captured ingridimages/fc4edd78-f361-4c4e-b675-9eabcb379437.png
# Captured ingridimages/470c0276-2d9c-485c-8ab3-0600f0ca78d9.png
# Captured ingridimages/a1adb213-0daa-4fad-af60-ba0acdb3adef.png
# Captured ingridimages/e551ad88-f38c-444e-af54-605bd0339559.png
# Captured ingridimages/a2ee4064-de27-40fb-b976-ea01653ab6eb.png
# Captured ingridimages/61572d7a-9b85-48ea-b776-76c26590b999.png

# %%
import uuid
import mss.tools
import time
import keyboard


time.sleep(5)
 
with mss.mss() as sct:
    monitor_info = sct.monitors[0]
    top_margin = monitor_info["height"] // 3
    monitor = {"top": monitor_info["top"] + top_margin, "left": monitor_info["left"]+55, "width": monitor_info["width"]-120, "height": (monitor_info["height"] * 2 // 3)-55}
 
    while not keyboard.is_pressed("space"):
        output = f"dataset/{str(uuid.uuid4())}.png".format(**monitor)
        sct_img = sct.grab(monitor)
        mss.tools.to_png(sct_img.rgb, sct_img.size, output=output)
        print(f"Captured {output}")
        time.sleep(0.5)

# %%
import uuid
import mss.tools
import time
import keyboard


time.sleep(5)
 
with mss.mss() as sct:
    monitor_info = sct.monitors[0]
    top_margin = monitor_info["height"] // 3
    monitor = {"top": monitor_info["top"] + top_margin, "left": monitor_info["left"]+55, "width": monitor_info["width"]-120, "height": (monitor_info["height"] * 2 // 3)-55}
 


    while True:
        if keyboard.is_pressed("space"):
            break
        output = f"ingridimages/{str(uuid.uuid4())}.png".format(**monitor)
        sct_img = sct.grab(monitor)
        mss.tools.to_png(sct_img.rgb, sct_img.size, output=output)
        print(f"Captured {output}")
        time.sleep(1)
# Out:
# Captured ingridimages/6b074874-9c79-483a-83b9-8bc13fe6bde0.png
# Captured ingridimages/c4501bec-e021-4266-a9a2-81765443f6a4.png
# Captured ingridimages/7a2ca3ad-124a-4e27-a5c9-48b54c08d337.png
# Captured ingridimages/6b0e7825-2af1-4ece-baf6-6d5fb8af3419.png
# Captured ingridimages/98941d09-c7b0-427e-b997-f4fdd7bcadca.png
# Captured ingridimages/531d4d1e-9c01-48ea-95b1-4d50d7b467fc.png
# Captured ingridimages/8ab03437-b90c-4dbe-a46f-2c0edb5a27a6.png
# Captured ingridimages/d80fa458-d394-40fe-a69d-2fc1ff04aad7.png
# Captured ingridimages/bef8b3e4-72d3-4c3e-8758-e0072274366b.png
# Captured ingridimages/2b44ab87-6922-468e-80f6-47405e0df562.png
# Captured ingridimages/ae25e6ac-27ad-4c95-9ea6-48addd1da556.png
# Captured ingridimages/cd0f3ef3-2e04-4494-a87a-d154da886533.png
# Captured ingridimages/d8011d15-582c-42a2-8cc4-600e636c8012.png
# Captured ingridimages/94097025-fe00-4d27-8a1f-93ca54c4dcda.png

# %%
# import the image
img_orig = cv2.imread('dataset/1489e9b8-f955-4a1c-a80d-f2b3d4207113.png')
plt.imshow(img_orig)

# %%
img_rgb = cv2.cvtColor(img_orig, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
# convert the image into gray scale
img_gray = cv2.cvtColor(img_orig, cv2.COLOR_BGR2GRAY)
plt.figure(figsize = (10, 10))
plt.imshow(img_gray, cmap = 'gray')
plt.axis('off')
# Out:
# (-0.5, 1799.5, 664.5, -0.5)

# %%
import cv2
img_orig = cv2.imread('dataset/9f191f48-fc18-42f2-b2cf-9badd9ae2192.png')
img_rgb = cv2.cvtColor(img_orig, cv2.COLOR_BGR2RGB)

# canny detection without blurring
#img_canny = cv2.Canny(img_rgb, threshold1=280, threshold2=400)
img_canny = cv2.Canny(img_orig, threshold1=280, threshold2=400)
plt.figure(figsize = (15, 15))
plt.subplot(1, 2, 1); plt.imshow(img_rgb)
plt.axis('off')
plt.subplot(1, 2, 2); plt.imshow(img_canny)
plt.axis('off')
# Out:
# (-0.5, 1799.5, 664.5, -0.5)

# %%
# set the lower and upper threshold
med_val = np.median(img_orig)
lower = int(max(0, .7 * med_val))
upper = int(min(255, 1.3 * med_val))

# blurring with ksize = 3
img_k3 = cv2.blur(img_orig, ksize = (3, 3))
# canny detection with different thresholds
edges_k3 = cv2.Canny(img_k3, threshold1 = lower, threshold2 = upper)
edges_k3_2 = cv2.Canny(img_k3, lower, upper + 75)

# blurring with ksize = 5 
img_k5 = cv2.blur(img_orig, ksize = (5, 5))
# canny detection with different thresholds
edges_k5 = cv2.Canny(img_k5, lower, upper)
edges_k5_2 = cv2.Canny(img_k5, lower, upper + 75)

# plot the images
images = [edges_k3, edges_k3_2, edges_k5, edges_k5_2]
titles = ['blurring, kernel = 3x3, lower threshold', 
          'blurring, kernel = 3x3, higher threshold', 
          'blurring, kernel = 5x5, lower threshold', 
          'blurring, kernel = 5x5, higher threshold']
plt.figure(figsize = (20, 15))
for i in range(4):
    plt.subplot(2, 2, i+1)
    plt.imshow(images[i])
    plt.axis('off')
    plt.title(titles[i])
        
plt.show()

# %%
print(len(lines))
# Out:
# 8

# %%
import math
if lines is not None:
    for i in range(0, len(lines)):
        rho = lines[i][0][0]
        theta = lines[i][0][1]
        a = math.cos(theta)
        b = math.sin(theta)
        x0 = a * rho
        y0 = b * rho
        pt1 = (int(x0 + 1000*(-b)), int(y0 + 1000*(a)))
        pt2 = (int(x0 - 1000*(-b)), int(y0 - 1000*(a)))
        cv2.line(cdst, pt1, pt2, (0,0,255), 3, cv2.LINE_AA)

# %%
plt.figure(figsize = (15, 15))
plt.subplot(1, 2, 1); plt.imshow(img_rgb)
plt.axis('off')
plt.subplot(1, 2, 2); plt.imshow(cdst)
plt.axis('off')
# Out:
# (-0.5, 1799.5, 664.5, -0.5)

# %%
#200, 251
#273
#287
linesP = cv2.HoughLinesP(img_canny, 1, np.pi / 180, 287, None, 50, 10)
    
if linesP is not None:
    for i in range(0, len(linesP)):
        l = linesP[i][0]
        cv2.line(cdstP, (l[0], l[1]), (l[2], l[3]), (0,0,255), 3, cv2.LINE_AA)

# %%
print(len(linesP))
# Out:
# 2

# %%
plt.figure(figsize = (15, 15))
plt.subplot(1, 2, 1); plt.imshow(img_rgb)
plt.axis('off')
plt.subplot(1, 2, 2); plt.imshow(cdstP)
plt.axis('off')
# Out:
# (-0.5, 1799.5, 664.5, -0.5)

# %%
cv2.imshow("Detected Lines (in red) - Standard Hough Line Transform", cdst)
cv2.imshow("Detected Lines (in red) - Probabilistic Line Transform", cdstP)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import sys
import math
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
#img_orig = cv.imread('dataset/0669c011-ce64-4564-a195-0c3f830e93bd.png')
img_orig = cv.imread('dataset/9f191f48-fc18-42f2-b2cf-9badd9ae2192.png')
img_rgb = cv.cvtColor(img_orig, cv.COLOR_BGR2RGB)


#img_canny = cv2.Canny(img_rgb, threshold1=321, threshold2=400)
img_blur = cv.blur(img_orig, ksize = (5, 5))
img_canny = cv.Canny(img_blur, threshold1=121.6, threshold2=180.9)
plt.figure(figsize = (15, 15))
plt.subplot(1, 2, 1); plt.imshow(img_rgb)
plt.axis('off')
plt.subplot(1, 2, 2); plt.imshow(img_canny)
plt.axis('off')
# Out:
# (-0.5, 1799.5, 664.5, -0.5)

# %%
cdst = cv.cvtColor(img_rgb, cv.COLOR_RGB2GRAY)
cdstP = np.copy(cdst)
lines = cv.HoughLines(img_canny, 1, np.pi / 180, 123, None, 0, 0)

# %%
import sys
import math
import cv2 as cv
import numpy as np
def main(argv):
   
   
    dst = img_canny
   
    # Copy edges to the images that will display the results in BGR
    cdst = cv.cvtColor(dst, cv.COLOR_GRAY2BGR)
    cdstP = np.copy(cdst)
 #67
    linesP = cv.HoughLinesP(dst, 1, np.pi / 250, 90, None, 94.6, 20.5)
    print(len(linesP))
    x1, y1, x2, y2 = 0
    if linesP is not None:
        for i in range(0, len(linesP)):
            l = linesP[i][0]
            x1, y1, x2, y2 = l[0]
            cv.line(cdstP, (l[0], l[1]), (l[2], l[3]), (0,0,255), 3, cv.LINE_AA)
            cv2.circle(cdstP, (x1, y1), 5, (0, 255, 255), -1)    # Mark starting point in yellow
            cv2.circle(cdstP, (x2, y2), 5, (0, 0, 255), -1)
   
    cv.imshow("Source", dst)
    cv.imshow("Detected Lines (in red) - Probabilistic Line Transform", cdstP)
   
    cv.waitKey()
    return 0
   
if __name__ == "__main__":
    main(sys.argv[1:])
# Out:
# 14
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\ingri\Documents\3ITF\AICourse\Project\Self-Driving-Mario-Kart\notebookIngrid.ipynb Cell 25 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X32sZmlsZQ%3D%3D?line=28'>29</a>     return 0
#      <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X32sZmlsZQ%3D%3D?line=30'>31</a> if __name__ == "__main__":
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X32sZmlsZQ%3D%3D?line=31'>32</a>     main(sys.argv[1:])
#
# c:\Users\ingri\Documents\3ITF\AICourse\Project\Self-Driving-Mario-Kart\notebookIngrid.ipynb Cell 25 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X32sZmlsZQ%3D%3D?line=13'>14</a> linesP = cv.HoughLinesP(dst, 1, np.pi / 250, 90, None, 94.6, 20.5)
#      <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X32sZmlsZQ%3D%3D?line=14'>15</a> print(len(linesP))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X32sZmlsZQ%3D%3D?line=15'>16</a> x1, y1, x2, y2 = 0
#      <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X32sZmlsZQ%3D%3D?line=16'>17</a> if linesP is not None:
#      <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X32sZmlsZQ%3D%3D?line=17'>18</a>     for i in range(0, len(linesP)):
#
# TypeError: cannot unpack non-iterable int object

# %% [markdown]
# Hi

# %%
def drive():
    img_orig = cv.imread('dataset/ff3d3968-af66-417d-bb6e-cfe517723969.png')
    img_blur = cv.blur(img_orig, ksize = (5, 5))
    img_canny = cv.Canny(img_blur, threshold1=121.6, threshold2=180.9)
    
    lines = cv.HoughLines(img_canny, 1, np.pi / 180, 123, None, 0, 0)

    dst = img_canny

    cdst = cv.cvtColor(dst, cv.COLOR_GRAY2BGR)
    cdstP = np.copy(cdst)
    linesP = cv.HoughLinesP(dst, 1, np.pi / 250, 90, None, 94.6, 20.5)
    print(len(linesP))
    if linesP is not None:
        for i in range(0, len(linesP)):
            l = linesP[i][0]
            cv.line(cdstP, (l[0], l[1]), (l[2], l[3]), (0,0,255), 3, cv.LINE_AA)
   
    cv.imshow("Source", dst)
    cv.imshow("Detected Lines (in red) - Probabilistic Line Transform", cdstP)
   
    cv.waitKey()

drive()
# Out:
# 9

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import mss.tools
import time
import uuid
import keyboard
import math
 
def drive():
    img_orig = cv.imread('./dataset/0fdfb641-f14c-45a6-8e8b-c9a701ff2937.png')
    img_rgb = cv.cvtColor(img_orig, cv.COLOR_BGR2RGB)
    img_blur = cv.blur(img_orig, ksize=(5, 5))
    img_canny = cv.Canny(img_blur, threshold1=121.6, threshold2=180.9)
    cdst = cv.cvtColor(img_rgb, cv.COLOR_RGB2GRAY)
    linesP = cv.HoughLinesP(img_canny, 1, np.pi / 250, 90, None, 94.6, 20.5)
   
    if linesP is not None:
        for i in range(0, len(linesP)):
            l = linesP[i][0]
            cv.line(cdst, (l[0], l[1]), (l[2], l[3]), (0, 0, 255), 3, cv.LINE_AA)
   
    image_width = 1800
    threshold = image_width // 2  # Half of the image width

    # Separate left and right coordinates based on the threshold
    left_y = []
    left_x = []
    right_y = []
    right_x = []

    for line in linesP:
        x1, y1, x2, y2 = line[0]
        # Separate coordinates into left and right sides
        if x1 < threshold and x2 < threshold:
            left_y.extend([y1, y2])
            left_x.extend([x1, x2])
        elif x1 >= threshold and x2 >= threshold:
            right_y.extend([y1, y2])
            right_x.extend([x1, x2])

    # Find the lowest Y coordinates on the left and right sides
    if left_y:
        left_lowest_index = left_y.index(min(left_y))
        x1_left_lowest, y1_left_lowest = left_x[left_lowest_index], left_y[left_lowest_index]
        cv.circle(cdst, (x1_left_lowest, y1_left_lowest), 10, (0, 0, 255), -1)  # Mark left lowest point in red

    if right_y:
        right_lowest_index = right_y.index(min(right_y))
        x2_right_lowest, y2_right_lowest = right_x[right_lowest_index], right_y[right_lowest_index]
        cv.circle(cdst, (x2_right_lowest, y2_right_lowest), 10, (0, 0, 255), -1)  # Mark right lowest point in red
 
    # Calculate Euclidean distance
    distance = math.sqrt((x2_right_lowest - x1_left_lowest) ** 2 + (y2_right_lowest - y1_left_lowest) ** 2)
    print("Euclidean distance:", distance)
 
    print("Distance between the points:", distance)
 
    center = distance / 2
    print('center:', center)
 
    cv.imshow("Detected Lines (in red) - Probabilistic Line Transform", cdst)
    cv.waitKey()
 
drive()
# Out:
# Distance between the points: 278.0395655298001
# center: 139.01978276490004

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import mss.tools
import time
import uuid
import keyboard
import math
import pyautogui
import time

def drive():
    img_orig = cv.imread('dataset/fd7f4e1f-1905-47ca-b00c-b2d1c6c7fd98.png')
    img_rgb = cv.cvtColor(img_orig, cv.COLOR_BGR2RGB)
    img_blur = cv.blur(img_orig, ksize=(5, 5))
    img_canny = cv.Canny(img_blur, threshold1=121.6, threshold2=180.9)
    cdst = cv.cvtColor(img_rgb, cv.COLOR_RGB2GRAY)
    linesP = cv.HoughLinesP(img_canny, 1, np.pi / 250, 90, None, 94.6, 20.5)
    
    if linesP is not None:
        for i in range(0, len(linesP)):
            l = linesP[i][0]
            cv.line(cdst, (l[0], l[1]), (l[2], l[3]), (0, 0, 255), 3, cv.LINE_AA)
    
    image_width = 1800
    threshold = image_width // 2  # Half of the image width

    # Separate left and right coordinates based on the threshold
    left_y = []
    left_x = []
    right_y = []
    right_x = []

    for line in linesP:
        x1, y1, x2, y2 = line[0]
        # Separate coordinates into left and right sides
        if x1 < threshold and x2 < threshold:
            left_y.extend([y1, y2])
            left_x.extend([x1, x2])
        elif x1 >= threshold and x2 >= threshold:
            right_y.extend([y1, y2])
            right_x.extend([x1, x2])

    # Find the lowest Y coordinates on the left and right sides
    if left_y:
        left_lowest_index = left_y.index(min(left_y))
        x1_left_lowest, y1_left_lowest = left_x[left_lowest_index], left_y[left_lowest_index]
        cv.circle(cdst, (x1_left_lowest, y1_left_lowest), 10, (0, 0, 255), -1)  # Mark left lowest point in red

    if right_y:
        right_lowest_index = right_y.index(min(right_y))
        x2_right_lowest, y2_right_lowest = right_x[right_lowest_index], right_y[right_lowest_index]
        cv.circle(cdst, (x2_right_lowest, y2_right_lowest), 10, (0, 0, 255), -1)  # Mark right lowest point in red

    # Calculate Euclidean distance
    distance = math.sqrt((x2_right_lowest - x1_left_lowest)**2 + (y2_right_lowest - y1_left_lowest)**2)

    print("Distance between the points:", distance)

    center = distance / 2
    print('center:', center)

    desired_x_point = x1_left_lowest + center
    mario_x_point = 900

    print('Desired x point:', desired_x_point)
    print(desired_x_point - mario_x_point)


    if(desired_x_point - mario_x_point) > 0:
        label = 'right'
    else:
        label = 'left'

    print(label)
    #cv.circle(cdst, (992, 300), 10, (0, 0, 255), -1)  # Mark left lowest point in red
    return label

    #cv.imshow("Detected Lines (in red) - Probabilistic Line Transform", cdst)
    #cv.waitKey()

label = drive()
def move(label):
    time.sleep(10)
    if (label == 'right'):
        keyboard.press('d')
        pyautogui.leftClick()
        time.sleep(2)
        keyboard.release('d')
        pyautogui.mouseUp()
move(label)
# Out:
# Distance between the points: 355.0507006048573
# center: 177.52535030242865
# Desired x point: 992.5253503024287
# 92.5253503024287
# right

# %%
# actual test
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import mss.tools
import time
import uuid
import keyboard
import math
import pyautogui
import time
import mss.tools
import uuid

def screenshot():
    with mss.mss() as sct:
        monitor_info = sct.monitors[0]
        top_margin = (monitor_info["height"] // 3) + 50
        monitor = {"top": monitor_info["top"] + top_margin, "left": monitor_info["left"] + 55, "width": monitor_info["width"] - 120, "height": (monitor_info["height"] * 2 // 3)-105}
        output = f"runningTest/{str(uuid.uuid4())}.png".format(**monitor)
        sct_img = sct.grab(monitor)
        mss.tools.to_png(sct_img.rgb, sct_img.size, output=output)
    return output
            
def drive():
    img_path = screenshot()
    img_orig = cv.imread(img_path)
    img_rgb = cv.cvtColor(img_orig, cv.COLOR_BGR2RGB)
    img_blur = cv.blur(img_orig, ksize=(5, 5))
    img_canny = cv.Canny(img_blur, threshold1=121.6, threshold2=180.9)
    cdst = cv.cvtColor(img_rgb, cv.COLOR_RGB2GRAY)
    linesP = cv.HoughLinesP(img_canny, 1, np.pi / 250, 90, None, 94.6, 20.5)
    
    if linesP is not None:
        for i in range(0, len(linesP)):
            l = linesP[i][0]
            cv.line(cdst, (l[0], l[1]), (l[2], l[3]), (0, 0, 255), 3, cv.LINE_AA)
    
    image_width = 1800
    threshold = image_width // 2  # Half of the image width

    # Separate left and right coordinates based on the threshold
    left_y = []
    left_x = []
    right_y = []
    right_x = []

    for line in linesP:
        x1, y1, x2, y2 = line[0]
        # Separate coordinates into left and right sides
        if x1 < threshold and x2 < threshold:
            left_y.extend([y1, y2])
            left_x.extend([x1, x2])
        elif x1 >= threshold and x2 >= threshold:
            right_y.extend([y1, y2])
            right_x.extend([x1, x2])

    # Find the lowest Y coordinates on the left and right sides
    if left_y:
        left_lowest_index = left_y.index(min(left_y))
        x1_left_lowest, y1_left_lowest = left_x[left_lowest_index], left_y[left_lowest_index]
        cv.circle(cdst, (x1_left_lowest, y1_left_lowest), 10, (0, 0, 255), -1)  # Mark left lowest point in red

    if right_y:
        right_lowest_index = right_y.index(min(right_y))
        x2_right_lowest, y2_right_lowest = right_x[right_lowest_index], right_y[right_lowest_index]
        cv.circle(cdst, (x2_right_lowest, y2_right_lowest), 10, (0, 0, 255), -1)  # Mark right lowest point in red

    # Calculate Euclidean distance
    distance = math.sqrt((x2_right_lowest - x1_left_lowest)**2 + (y2_right_lowest - y1_left_lowest)**2)

    print("Distance between the points:", distance)

    center = distance / 2
    print('center:', center)

    desired_x_point = x1_left_lowest + center
    mario_x_point = 900

    print('Desired x point:', desired_x_point)
    print(desired_x_point - mario_x_point)


    if(desired_x_point - mario_x_point) > 0:
        label = 'right'
    else:
        label = 'left'

    print(label)
    #cv.circle(cdst, (992, 300), 10, (0, 0, 255), -1)  # Mark left lowest point in red
    return label

    #cv.imshow("Detected Lines (in red) - Probabilistic Line Transform", cdst)
    #cv.waitKey()

def move():
    label = drive()
    print(label)
    if (label == 'right'):
        keyboard.press('d')
        pyautogui.mouseDown()
        time.sleep(0.2)
        pyautogui.mouseUp()
        keyboard.release('d')
        #time.sleep(0.5)
    if (label == 'left'):
        keyboard.press('q')
        pyautogui.mouseDown()
        time.sleep(0.2)
        pyautogui.mouseUp()
        keyboard.release('q')
        #time.sleep(0.5)


time.sleep(5)
while not keyboard.is_pressed("space"):
    move()
    time.sleep(0.8)
# Out:
# Distance between the points: 1160.6222469003426
# center: 580.3111234501713
# Desired x point: 1075.3111234501712
# 175.31112345017118
# right
# right
# Distance between the points: 602.0
# center: 301.0
# Desired x point: 964.0
# 64.0
# right
# right
# Distance between the points: 792.0
# center: 396.0
# Desired x point: 874.0
# -26.0
# left
# left
# Distance between the points: 562.355759284103
# center: 281.1778796420515
# Desired x point: 1062.1778796420515
# 162.1778796420515
# right
# right
# Distance between the points: 855.0005847951217
# center: 427.5002923975608
# Desired x point: 1174.5002923975608
# 274.50029239756077
# right
# right
# Distance between the points: 263.0684321616716
# center: 131.5342160808358
# Desired x point: 980.5342160808358
# 80.53421608083579
# right
# right
# Distance between the points: 1057.760369838084
# center: 528.880184919042
# Desired x point: 813.880184919042
# -86.119815080958
# left
# left
# Distance between the points: 721.4991337486138
# center: 360.7495668743069
# Desired x point: 984.7495668743069
# 84.74956687430688
# right
# right
# Distance between the points: 1140.9136689513366
# center: 570.4568344756683
# Desired x point: 853.4568344756683
# -46.5431655243317
# left
# left
# Distance between the points: 878.2511030451371
# center: 439.12555152256857
# Desired x point: 633.1255515225686
# -266.87444847743143
# left
# left
# Distance between the points: 572.4377695435549
# center: 286.2188847717774
# Desired x point: 942.2188847717774
# 42.218884771777425
# right
# right
# Distance between the points: 862.4268084886972
# center: 431.2134042443486
# Desired x point: 647.2134042443486
# -252.78659575565143
# left
# left
# Distance between the points: 642.2164744071893
# center: 321.1082372035946
# Desired x point: 841.1082372035946
# -58.891762796405374
# left
# left
# Distance between the points: 592.2161767462959
# center: 296.10808837314795
# Desired x point: 1047.108088373148
# 147.1080883731479
# right
# right
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# c:\Users\ingri\Documents\3ITF\AICourse\Project\Self-Driving-Mario-Kart\notebookIngrid.ipynb Cell 29 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X40sZmlsZQ%3D%3D?line=114'>115</a> time.sleep(5)
#     <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X40sZmlsZQ%3D%3D?line=115'>116</a> while not keyboard.is_pressed("space"):
# --> <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X40sZmlsZQ%3D%3D?line=116'>117</a>     move()
#     <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X40sZmlsZQ%3D%3D?line=117'>118</a>     time.sleep(0.8)
#
# c:\Users\ingri\Documents\3ITF\AICourse\Project\Self-Driving-Mario-Kart\notebookIngrid.ipynb Cell 29 line 9
#      <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X40sZmlsZQ%3D%3D?line=95'>96</a> def move():
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X40sZmlsZQ%3D%3D?line=96'>97</a>     label = drive()
#      <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X40sZmlsZQ%3D%3D?line=97'>98</a>     print(label)
#      <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X40sZmlsZQ%3D%3D?line=98'>99</a>     if (label == 'right'):
#
# c:\Users\ingri\Documents\3ITF\AICourse\Project\Self-Driving-Mario-Kart\notebookIngrid.ipynb Cell 29 line 7
#      <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X40sZmlsZQ%3D%3D?line=66'>67</a>     cv.circle(cdst, (x2_right_lowest, y2_right_lowest), 10, (0, 0, 255), -1)  # Mark right lowest point in red
#      <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X40sZmlsZQ%3D%3D?line=68'>69</a> # Calculate Euclidean distance
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X40sZmlsZQ%3D%3D?line=69'>70</a> distance = math.sqrt((x2_right_lowest - x1_left_lowest)**2 + (y2_right_lowest - y1_left_lowest)**2)
#      <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X40sZmlsZQ%3D%3D?line=71'>72</a> print("Distance between the points:", distance)
#      <a href='vscode-notebook-cell:/c%3A/Users/ingri/Documents/3ITF/AICourse/Project/Self-Driving-Mario-Kart/notebookIngrid.ipynb#X40sZmlsZQ%3D%3D?line=73'>74</a> center = distance / 2
#
# UnboundLocalError: cannot access local variable 'x2_right_lowest' where it is not associated with a value

# %%
# actual test
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import mss.tools
import time
import uuid
import keyboard
import math
import pyautogui
import time
import mss.tools
import uuid

def screenshot():
    with mss.mss() as sct:
        time.sleep(1)
        monitor_info = sct.monitors[0]
        top_margin = (monitor_info["height"] // 3) + 50
        monitor = {"top": monitor_info["top"] + top_margin, "left": monitor_info["left"] + 55, "width": monitor_info["width"] - 120, "height": (monitor_info["height"] * 2 // 3)-105}
        output = f"runningTest/{str(uuid.uuid4())}.png".format(**monitor)
        sct_img = sct.grab(monitor)
        mss.tools.to_png(sct_img.rgb, sct_img.size, output=output)
    return output
            
def drive():
    img_path = screenshot()
    img_orig = cv.imread(img_path)
    img_rgb = cv.cvtColor(img_orig, cv.COLOR_BGR2RGB)
    img_blur = cv.blur(img_orig, ksize=(5, 5))
    img_canny = cv.Canny(img_blur, threshold1=121.6, threshold2=180.9)
    cdst = cv.cvtColor(img_rgb, cv.COLOR_RGB2GRAY)
    linesP = cv.HoughLinesP(img_canny, 1, np.pi / 250, 90, None, 94.6, 20.5)
    
    if linesP is not None:
        for i in range(0, len(linesP)):
            l = linesP[i][0]
            cv.line(cdst, (l[0], l[1]), (l[2], l[3]), (0, 0, 255), 3, cv.LINE_AA)
    
    image_width = 1800
    threshold = image_width // 2  # Half of the image width

    # Separate left and right coordinates based on the threshold
    left_y = []
    left_x = []
    right_y = []
    right_x = []
    if linesP is not None:
        for line in linesP:
            x1, y1, x2, y2 = line[0]
            # Separate coordinates into left and right sides
            if x1 < threshold and x2 < threshold:
                left_y.extend([y1, y2])
                left_x.extend([x1, x2])
            elif x1 >= threshold and x2 >= threshold:
                right_y.extend([y1, y2])
                right_x.extend([x1, x2])

    # Find the lowest Y coordinates on the left and right sides
    if left_y:
        left_lowest_index = left_y.index(min(left_y))
        x1_left_lowest, y1_left_lowest = left_x[left_lowest_index], left_y[left_lowest_index]
        cv.circle(cdst, (x1_left_lowest, y1_left_lowest), 10, (0, 0, 255), -1)  # Mark left lowest point in red

    if right_y:
        right_lowest_index = right_y.index(min(right_y))
        x2_right_lowest, y2_right_lowest = right_x[right_lowest_index], right_y[right_lowest_index]
        cv.circle(cdst, (x2_right_lowest, y2_right_lowest), 10, (0, 0, 255), -1)  # Mark right lowest point in red

    if right_y and left_y:
        # Calculate Euclidean distance
        distance = math.sqrt((x2_right_lowest - x1_left_lowest)**2 + (y2_right_lowest - y1_left_lowest)**2)

        print("Distance between the points:", distance)

        center = distance / 2
        print('center:', center)

        desired_x_point = x1_left_lowest + center
        mario_x_point = 900

        print('Desired x point:', desired_x_point)
        print(desired_x_point - mario_x_point)


        if(desired_x_point - mario_x_point) > 0:
            label = 'right'
        else:
            label = 'left'

        print(label)
        #cv.circle(cdst, (992, 300), 10, (0, 0, 255), -1)  # Mark left lowest point in red
        return label
    if right_y and not left_y:
        label = 'right'
        return label
    if left_y and not right_y:
        label = 'left'
        return label

    #cv.imshow("Detected Lines (in red) - Probabilistic Line Transform", cdst)
    #cv.waitKey()

def move():
    label = drive()
    print(label)
    if (label == 'right'):
        keyboard.press('d')
        pyautogui.mouseDown()
        pyautogui.mouseUp()
        keyboard.release('d')
        time.sleep(0.5)
    if (label == 'left'):
        keyboard.press('q')
        pyautogui.mouseDown()
        pyautogui.mouseUp()
        keyboard.release('q')
        time.sleep(0.5)

time.sleep(5)
while not keyboard.is_pressed("space"):
    move()
    time.sleep(1)

# %%
# actual test
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import mss.tools
import time
import uuid
import keyboard
import math
import pyautogui
import time
import mss.tools
import uuid

def screenshot():
    with mss.mss() as sct:
        time.sleep(1)
        monitor_info = sct.monitors[0]
        top_margin = (monitor_info["height"] // 3) + 50
        monitor = {"top": monitor_info["top"] + top_margin, "left": monitor_info["left"] + 55, "width": monitor_info["width"] - 120, "height": (monitor_info["height"] * 2 // 3)-105}
        output = f"testimages/{str(uuid.uuid4())}.png".format(**monitor)
        sct_img = sct.grab(monitor)
        mss.tools.to_png(sct_img.rgb, sct_img.size, output=output)
    return output
            
def drive():
    img_path = screenshot()
    img_orig = cv.imread(img_path)
    img_rgb = cv.cvtColor(img_orig, cv.COLOR_BGR2RGB)
    img_blur = cv.blur(img_orig, ksize=(5, 5))
    img_canny = cv.Canny(img_blur, threshold1=121.6, threshold2=180.9)
    cdst = cv.cvtColor(img_rgb, cv.COLOR_RGB2GRAY)
    linesP = cv.HoughLinesP(img_canny, 1, np.pi / 250, 90, None, 94.6, 20.5)
    
    if linesP is not None:
        for i in range(0, len(linesP)):
            l = linesP[i][0]
            cv.line(cdst, (l[0], l[1]), (l[2], l[3]), (0, 0, 255), 3, cv.LINE_AA)
    
    image_width = 1800
    threshold = image_width // 2  # Half of the image width

    # Separate left and right coordinates based on the threshold
    left_y = []
    left_x = []
    right_y = []
    right_x = []
    if linesP is not None:
        for line in linesP:
            x1, y1, x2, y2 = line[0]
            # Separate coordinates into left and right sides
            if x1 < threshold and x2 < threshold:
                left_y.extend([y1, y2])
                left_x.extend([x1, x2])
            elif x1 >= threshold and x2 >= threshold:
                right_y.extend([y1, y2])
                right_x.extend([x1, x2])

    # Find the lowest Y coordinates on the left and right sides
    if left_y:
        left_lowest_index = left_y.index(min(left_y))
        x1_left_lowest, y1_left_lowest = left_x[left_lowest_index], left_y[left_lowest_index]
        cv.circle(cdst, (x1_left_lowest, y1_left_lowest), 10, (0, 0, 255), -1)  # Mark left lowest point in red

    if right_y:
        right_lowest_index = right_y.index(min(right_y))
        x2_right_lowest, y2_right_lowest = right_x[right_lowest_index], right_y[right_lowest_index]
        cv.circle(cdst, (x2_right_lowest, y2_right_lowest), 10, (0, 0, 255), -1)  # Mark right lowest point in red


    if right_y and not left_y:
        label = 'right'
        print("right line only")
        return label
        
    elif left_y and not right_y:
        label = 'left'
        print("left line only")
        return label
    elif right_y and left_y:
        # Calculate Euclidean distance
        distance = math.sqrt((x2_right_lowest - x1_left_lowest)**2 + (y2_right_lowest - y1_left_lowest)**2)

        print("Distance between the points:", distance)

        center = distance / 2
        print('center:', center)

        desired_x_point = x1_left_lowest + center
        mario_x_point = 900

        print('Desired x point:', desired_x_point)
        print(desired_x_point - mario_x_point)


        if(desired_x_point - mario_x_point) > 0:
            label = 'right'
        else:
            label = 'left'

        print(label)
        #cv.circle(cdst, (992, 300), 10, (0, 0, 255), -1)  # Mark left lowest point in red
        return label
   

    #cv.imshow("Detected Lines (in red) - Probabilistic Line Transform", cdst)
    #cv.waitKey()

def move():
    label = drive()
    print(label)
    if (label == 'right'):
        keyboard.press('d')
        pyautogui.mouseDown()
        time.sleep(0.15)
        pyautogui.mouseUp()
        keyboard.release('d')
        #time.sleep(0.5)
    if (label == 'left'):
        keyboard.press('q')
        pyautogui.mouseDown()
        time.sleep(0.15)
        pyautogui.mouseUp()
        keyboard.release('q')
        #time.sleep(0.5)

time.sleep(5)
while not keyboard.is_pressed("space"):
    move()
    #time.sleep(1)

# %% [markdown]
# ### The working code

# %%
# actual test
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import mss.tools
import time
import uuid
import keyboard
import math
import pyautogui
import time
import mss.tools
import uuid

def screenshot():
    with mss.mss() as sct:
        time.sleep(1)
        monitor_info = sct.monitors[0]
        top_margin = (monitor_info["height"] // 3) + 50
        monitor = {"top": monitor_info["top"] + top_margin, "left": monitor_info["left"] + 55, "width": monitor_info["width"] - 120, "height": (monitor_info["height"] * 2 // 3)-105}
        output = f"testimages/{str(uuid.uuid4())}.png".format(**monitor)
        sct_img = sct.grab(monitor)
        mss.tools.to_png(sct_img.rgb, sct_img.size, output=output)
    return output
            
def drive():
    img_path = screenshot()
    img_orig = cv.imread(img_path)
    img_rgb = cv.cvtColor(img_orig, cv.COLOR_BGR2RGB)
    img_blur = cv.blur(img_orig, ksize=(5, 5))
    img_canny = cv.Canny(img_blur, threshold1=121.6, threshold2=180.9)
    cdst = cv.cvtColor(img_rgb, cv.COLOR_RGB2GRAY)
    linesP = cv.HoughLinesP(img_canny, 1, np.pi / 250, 90, None, 94.6, 20.5)
    
    if linesP is not None:
        for i in range(0, len(linesP)):
            l = linesP[i][0]
            cv.line(cdst, (l[0], l[1]), (l[2], l[3]), (0, 0, 255), 3, cv.LINE_AA)
    
    image_width = 1800
    threshold = image_width // 2  # Half of the image width

    # Separate left and right coordinates based on the threshold
    left_y = []
    left_x = []
    right_y = []
    right_x = []
    if linesP is not None:
        for line in linesP:
            x1, y1, x2, y2 = line[0]
            # Separate coordinates into left and right sides
            if x1 < threshold and x2 < threshold:
                left_y.extend([y1, y2])
                left_x.extend([x1, x2])
            elif x1 >= threshold and x2 >= threshold:
                right_y.extend([y1, y2])
                right_x.extend([x1, x2])

    # Find the lowest Y coordinates on the left and right sides
    if left_y:
        left_lowest_index = left_y.index(min(left_y))
        x1_left_lowest, y1_left_lowest = left_x[left_lowest_index], left_y[left_lowest_index]
        cv.circle(cdst, (x1_left_lowest, y1_left_lowest), 10, (0, 0, 255), -1)  # Mark left lowest point in red

    if right_y:
        right_lowest_index = right_y.index(min(right_y))
        x2_right_lowest, y2_right_lowest = right_x[right_lowest_index], right_y[right_lowest_index]
        cv.circle(cdst, (x2_right_lowest, y2_right_lowest), 10, (0, 0, 255), -1)  # Mark right lowest point in red


    if right_y and not left_y:
        label = 'right'
        print("right line only")
        return label
        
    elif left_y and not right_y:
        label = 'left'
        print("left line only")
        return label
    elif right_y and left_y:
        # Calculate Euclidean distance
        distance = math.sqrt((x2_right_lowest - x1_left_lowest)**2 + (y2_right_lowest - y1_left_lowest)**2)

        print("Distance between the points:", distance)

        center = distance / 2
        print('center:', center)

        desired_x_point = x1_left_lowest + center
        mario_x_point = 900

        print('Desired x point:', desired_x_point)
        print(desired_x_point - mario_x_point)


        if(desired_x_point - mario_x_point) > 0:
            label = 'right'
        else:
            label = 'left'

        print(label)
        #cv.circle(cdst, (992, 300), 10, (0, 0, 255), -1)  # Mark left lowest point in red
        return label
   

    #cv.imshow("Detected Lines (in red) - Probabilistic Line Transform", cdst)
    #cv.waitKey()

def move():
    label = drive()
    print(label)
    if (label == 'right'):
        keyboard.press('d')
        pyautogui.mouseDown()
        time.sleep(0.15)
        pyautogui.mouseUp()
        keyboard.release('d')
        #time.sleep(0.5)
    if (label == 'left'):
        keyboard.press('q')
        pyautogui.mouseDown()
        time.sleep(0.15)
        pyautogui.mouseUp()
        keyboard.release('q')
        #time.sleep(0.5)

time.sleep(5)
while not keyboard.is_pressed("space"):
    move()
    #time.sleep(1)

# %%
print("Git sucks")
# Out:
# Git sucks
